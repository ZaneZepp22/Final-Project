# %%
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
arr = pd.read_csv("Arrest_Data.csv", index_col = "INCIDENTNEIGHBORHOOD")
del arr['INCIDENTZONE']
arr.head(10)
# Out:
#                            PK       CCR   AGE GENDER RACE  \
# INCIDENTNEIGHBORHOOD
# Bloomfield            1975272  16158872  42.0      F    B
# Outside City          1974456  16144120  31.0      M    W
# Westwood              1974466  16144165  63.0      F    B
# East Allegheny        1974550  16145257  25.0      F    W
# Crafton Heights       1974596  16145962  25.0      M    B
# Greenfield            1974556  16144301  45.0      M    W
# Brookline             1974628  16147655  29.0      M    W
# Regent Square         1974607  16146037  21.0      F    B
# East Liberty          1974643  16132537  17.0      M    B
# NaN                   1974647  16138646  14.0      M    B
#
#                                ARRESTTIME  \
# INCIDENTNEIGHBORHOOD
# Bloomfield            2016-08-24T12:20:00
# Outside City          2016-08-03T14:55:00
# Westwood              2016-08-03T16:45:00
# East Allegheny        2016-08-05T02:36:00
# Crafton Heights       2016-08-06T02:00:00
# ...

# %%
fire = pd.read_csv("Fire_Incidents.csv", index_col = "neighborhood")
fire = fire.drop(['fire_zone', 'pli_division','alarms','alarm_time','ward', 'call_no','type_description','address','tract','incident_type','primary_unit',''], axis=1)
fire.head(10)
# Out:
#                           incident_type primary_unit  census_tract  \
# neighborhood
# NaN                               111.0      231EN16           NaN
# NaN                               111.0      231EN16           NaN
# NaN                               131.0      231EN32        2406.0
# Fineview                          131.0      231EN38        2509.0
# Fairywood                         111.0      231EN31        2808.0
# South Side Flats                  150.0      231EN24        1702.0
# Allegheny Center                  113.0      231EN32        2204.0
# Lincoln-Lemington-Belmar          111.0      231EN15        1203.0
# Carrick                           111.0      231EN23        2904.0
# Beechview                         131.0      231EN28        1916.0
#
#                           council_district  public_works_division  \
# neighborhood
# NaN                                    NaN                    NaN
# ...
